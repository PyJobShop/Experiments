# %%
from pathlib import Path

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Constants

# %%
DATA_DIR = Path("../data")

SOLVERS = ["ortools", "cpoptimizer"]
TIME_LIMIT = [900]

SET1 = ["JSP", "FJSP", "NW-PFSP", "NPFSP", "HFSP"]
SET2 = ["PFSP", "SDST-PFSP", "TCT-PFSP", "TT-PFSP"]
SET3 = ["RCPSP", "MMRCPSP", "RCMPSP"]

ALL = SET1 + SET2 + SET3

# %% [markdown]
# ## Helpers

# %%
def present(df, index=ALL):
    """
    Put time limit and solver as MultiIndex and sort by time limit and OR-tools first.
    """
    unstacked = df.unstack(level=[2, 1])
    columns = sorted(unstacked.columns, key=lambda x: (x[0], -ord(x[1][0])))
    unstacked = unstacked[columns]
    return unstacked.loc[index]

# %%
def latex(df, float_format="%.2f"):
    text = df.to_latex(float_format=float_format)
    text = text.replace("time_limit", "Time Limit")
    text = text.replace("_", "-")
    text = text.replace("NaN", "-")
    print(text)

# %% [markdown]
# ## Merging

# %%
bks = pd.read_csv(DATA_DIR / "bks.csv")
stats = pd.read_csv(DATA_DIR / "stats.csv")
results = pd.read_csv(DATA_DIR / "results.csv")

df = pd.merge(results, bks, on=["problem", "instance"])
# assert len(df) == len(results), "Not all results have a BKS entry."

df = pd.merge(df, stats, on=["problem", "instance"])
# assert len(df) == len(results), "Not all results have instance stats."

# %% [markdown]
# Debug cell to check which results don't have any bks. As long as these are "0.txt" instances, which are test instances, then it's fine.

# %%
merged = results.merge(bks, on=['problem', 'instance'], how='left', indicator=True)
not_in_bks = merged[merged['_merge'] == 'left_only']
not_in_bks['instance'].unique()
# Out:
# array(['0.txt'], dtype=object)

# %% [markdown]
# ## Preprocessing

# %%
def calculate_rpd(row):
    if row["bks"] != 0:
        return ((row["objective"] - row["bks"]) / row["bks"]) * 100
    else:
        # When the BKS is zero and objective is zero, we set RPD to 0, 
        # otherwise set to 100.
        return 0 if row["objective"] == row["bks"] else 100

def calculate_gap(row):
    if row["objective"] != 0:
        return ((row["objective"] - row["lower_bound"]) / row["objective"]) * 100
    else:
        # When the objective is zero, we set RPD to 0, otherwise set to 100.
        return 0 if row["objective"] == row["bks"] else 100
        
def preprocess(df):
    df = df.copy()
    
    df["rpd"] = df.apply(calculate_rpd, axis=1)
    if "lower_bound" in df.columns:
        df["gap"] = df.apply(calculate_gap, axis=1)
    df["feas"] = df["status"].isin(["Optimal", "Feasible"])
    df["optimal"] = df["status"] == "Optimal"
    df["large"] = df["num_modes"] >= 5000
    
    return df

# %%
df = preprocess(df)

# %% [markdown]
# ### Instance statistics

# %%
def agg_stats(x):
    return pd.Series({
        'min': x.min(),
        'avg': round(x.mean()),
        'max': x.max()
    })

# this ensures we only have each instance once (instead of 4x)
subset = df[df['solver'] == 'ortools'] 

result = subset.groupby("problem").agg({
    'num_modes': ['count', 'min', 'mean', 'max'],
    # 'num_tasks': ['count', 'min', 'mean', 'max'],
    'num_resources': ['min', 'mean', 'max']
}).round(0)

columns = pd.MultiIndex.from_tuples([
    ('', 'instances'),
    ('Tasks', 'min'),
    ('Tasks', 'avg'),
    ('Tasks', 'max'),
    ('Resources', 'min'),
    ('Resources', 'avg'),
    ('Resources', 'max')
])

result.columns = columns
result = result.loc[ALL] # sort

for col in result.columns:
    result[col] = result[col].astype(int)

print(result.to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
#  &  & \multicolumn{3}{r}{Tasks} & \multicolumn{3}{r}{Resources} \\
#  & instances & min & avg & max & min & avg & max \\
# problem &  &  &  &  &  &  &  \\
# \midrule
# JSP & 242 & 36 & 511 & 2000 & 5 & 15 & 20 \\
# FJSP & 289 & 33 & 1581 & 14401 & 4 & 11 & 20 \\
# NW-PFSP & 360 & 100 & 12610 & 48000 & 5 & 31 & 60 \\
# NPFSP & 360 & 100 & 12610 & 48000 & 5 & 31 & 60 \\
# HFSP & 1440 & 750 & 3750 & 10000 & 15 & 30 & 50 \\
# PFSP & 120 & 100 & 1496 & 6000 & 5 & 19 & 60 \\
# SDST-PFSP & 360 & 100 & 661 & 2000 & 5 & 12 & 20 \\
# TCT-PFSP & 120 & 100 & 1496 & 6000 & 5 & 19 & 60 \\
# TT-PFSP & 135 & 500 & 1500 & 2500 & 10 & 30 & 50 \\
# RCPSP & 2520 & 32 & 122 & 302 & 3 & 4 & 4 \\
# MMRCPSP & 1080 & 152 & 227 & 302 & 4 & 4 & 4 \\
# RCMPSP & 2254 & 1488 & 1488 & 1488 & 4 & 4 & 4 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Feasibility

# %%
def percentage_feasible(feas):
    return sum(feas) / len(feas) * 100

groups = df.groupby(["problem", "solver", "time_limit"])
pct_feas = groups['feas'].apply(percentage_feasible)
latex(present(pct_feas), float_format= "%.2f")
# Out:
# \begin{tabular}{lrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer \\
# problem &  &  \\
# \midrule
# JSP & 100.00 & 100.00 \\
# FJSP & 100.00 & 100.00 \\
# NW-PFSP & 100.00 & 100.00 \\
# NPFSP & 100.00 & 100.00 \\
# HFSP & 100.00 & 100.00 \\
# PFSP & 100.00 & 100.00 \\
# SDST-PFSP & 100.00 & 100.00 \\
# TCT-PFSP & 100.00 & 100.00 \\
# TT-PFSP & 100.00 & 100.00 \\
# RCPSP & 100.00 & 100.00 \\
# MMRCPSP & 100.00 & 94.07 \\
# RCMPSP & 100.00 & 100.00 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Optimal

# %%
def percentage_opt(row):
    return sum(row) / len(row) * 100

groups = df.groupby(["problem", "solver", "time_limit"])
pct_opt = groups['optimal'].apply(percentage_opt)
latex(present(pct_opt), float_format= "%.2f")
# Out:
# \begin{tabular}{lrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer \\
# problem &  &  \\
# \midrule
# JSP & 41.32 & 47.11 \\
# FJSP & 58.13 & 38.41 \\
# NW-PFSP & 0.00 & 0.00 \\
# NPFSP & 6.11 & 8.06 \\
# HFSP & 0.14 & 0.00 \\
# PFSP & 17.50 & 30.83 \\
# SDST-PFSP & 0.00 & 1.11 \\
# TCT-PFSP & 0.00 & 0.00 \\
# TT-PFSP & 5.93 & 6.67 \\
# RCPSP & 65.16 & 64.64 \\
# MMRCPSP & 79.63 & 68.89 \\
# RCMPSP & 9.94 & 8.78 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Relative percentage deviation

# %%
def rpd(df, groups=["problem", "solver", "time_limit"]):
    subset = df[df["feas"]] # drop rows with infeasible solutions
    grouped = subset.groupby(groups)
    return grouped['rpd'].mean().round(2)

# %%
res = present(rpd(df))
latex(res)
res
# Out:
# \begin{tabular}{lrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer \\
# problem &  &  \\
# \midrule
# JSP & 1.98 & 1.80 \\
# FJSP & 0.68 & 0.99 \\
# NW-PFSP & 3.47 & 7.18 \\
# NPFSP & 13.53 & 8.88 \\
# HFSP & 13.34 & 6.58 \\
# PFSP & 7.49 & 2.54 \\
# SDST-PFSP & 8.82 & 4.41 \\
# TCT-PFSP & 10.31 & 3.31 \\
# TT-PFSP & 53.14 & 20.79 \\
# RCPSP & 0.93 & 0.46 \\
# MMRCPSP & 0.21 & 0.35 \\
# RCMPSP & -0.52 & -0.85 \\
# \bottomrule
# \end{tabular}
# time_limit     900
# solver     ortools cpoptimizer
# problem
# JSP           1.98        1.80
# FJSP          0.68        0.99
# NW-PFSP       3.47        7.18
# NPFSP        13.53        8.88
# HFSP         13.34        6.58
# PFSP          7.49        2.54
# SDST-PFSP     8.82        4.41
# TCT-PFSP     10.31        3.31
# TT-PFSP      53.14       20.79
# RCPSP         0.93        0.46
# MMRCPSP       0.21        0.35
# RCMPSP       -0.52       -0.85

# %%
for instance_set in [SET1, SET2, SET3]:
    avg_gaps = res.loc[instance_set].mean().round(2).values
    text = '  &  '.join(str(gap) for gap in avg_gaps)
    print(f"& \\textit{{Average}} & {text} \\\\")
# Out:
# & \textit{Average} & 6.6  &  5.09 \\
# & \textit{Average} & 19.94  &  7.76 \\
# & \textit{Average} & 0.21  &  -0.01 \\

# %% [markdown]
# ### RPD by instance size

# %%
res = rpd(df, ["problem", "solver", "large"])
res = present(res)
latex(res)
res
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# large & \multicolumn{2}{r}{False} & \multicolumn{2}{r}{True} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 1.98 & 1.80 & - & - \\
# FJSP & 0.49 & 0.69 & 2.57 & 3.87 \\
# NW-PFSP & 6.22 & 3.70 & 1.72 & 9.40 \\
# NPFSP & 9.07 & 4.70 & 16.36 & 11.54 \\
# HFSP & 8.63 & 5.42 & 23.72 & 9.12 \\
# PFSP & 6.49 & 2.00 & 18.49 & 8.50 \\
# SDST-PFSP & 8.82 & 4.41 & - & - \\
# TCT-PFSP & 10.39 & 3.22 & 9.41 & 4.33 \\
# TT-PFSP & 53.14 & 20.79 & - & - \\
# RCPSP & 0.93 & 0.46 & - & - \\
# MMRCPSP & 0.21 & 0.35 & - & - \\
# RCMPSP & -0.52 & -0.85 & - & - \\
# \bottomrule
# \end{tabular}
# large       False               True
# solver    ortools cpoptimizer ortools cpoptimizer
# problem
# JSP          1.98        1.80     NaN         NaN
# FJSP         0.49        0.69    2.57        3.87
# NW-PFSP      6.22        3.70    1.72        9.40
# NPFSP        9.07        4.70   16.36       11.54
# HFSP         8.63        5.42   23.72        9.12
# PFSP         6.49        2.00   18.49        8.50
# SDST-PFSP    8.82        4.41     NaN         NaN
# TCT-PFSP    10.39        3.22    9.41        4.33
# TT-PFSP     53.14       20.79     NaN         NaN
# RCPSP        0.93        0.46     NaN         NaN
# MMRCPSP      0.21        0.35     NaN         NaN
# RCMPSP      -0.52       -0.85     NaN         NaN

# %%
for instance_set in [SET1, SET2, SET3]:
    avg_gaps = res.loc[instance_set].mean().round(2).values
    text = '  &  '.join(str(gap) for gap in avg_gaps)
    print(f"& \\textit{{Average}} & {text} \\\\")
# Out:
# & \textit{Average} & 5.28  &  3.26  &  11.09  &  8.48 \\
# & \textit{Average} & 19.71  &  7.6  &  13.95  &  6.42 \\
# & \textit{Average} & 0.21  &  -0.01  &  nan  &  nan \\

# %% [markdown]
# ## Optimality gap

# %%
def gap(df, groups=["problem", "solver", "time_limit"]):
    subset = df[df["feas"]] # drop rows with infeasible solutions
    grouped = subset.groupby(groups)
    return grouped['gap'].mean().round(2)

# %%
res = present(gap(df))
latex(res)
res
# Out:
# \begin{tabular}{lrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer \\
# problem &  &  \\
# \midrule
# JSP & 3.40 & 4.09 \\
# FJSP & 1.04 & 27.67 \\
# NW-PFSP & 50.51 & 57.87 \\
# NPFSP & 16.29 & 25.58 \\
# HFSP & 11.94 & 66.54 \\
# PFSP & 10.61 & 7.03 \\
# SDST-PFSP & 30.75 & 28.24 \\
# TCT-PFSP & 21.48 & 26.69 \\
# TT-PFSP & 66.86 & 72.43 \\
# RCPSP & 3.46 & 4.26 \\
# MMRCPSP & 1.03 & 7.30 \\
# RCMPSP & 14.91 & 67.36 \\
# \bottomrule
# \end{tabular}
# time_limit     900
# solver     ortools cpoptimizer
# problem
# JSP           3.40        4.09
# FJSP          1.04       27.67
# NW-PFSP      50.51       57.87
# NPFSP        16.29       25.58
# HFSP         11.94       66.54
# PFSP         10.61        7.03
# SDST-PFSP    30.75       28.24
# TCT-PFSP     21.48       26.69
# TT-PFSP      66.86       72.43
# RCPSP         3.46        4.26
# MMRCPSP       1.03        7.30
# RCMPSP       14.91       67.36

# %% [markdown]
# ## Results

# %%
df = preprocess(df)
tl900 = df[df["feas"]]
res = tl900.groupby(["problem","solver"])[['rpd', 'gap']].mean()
unstacked = res.unstack()
columns = sorted(unstacked.columns, key=lambda x: (-ord(x[0][0]), -ord(x[1][0])))
unstacked = unstacked[columns]
res = unstacked.loc[ALL]
latex(res)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#  & \multicolumn{2}{r}{rpd} & \multicolumn{2}{r}{gap} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 1.98 & 1.80 & 3.40 & 4.09 \\
# FJSP & 0.68 & 0.99 & 1.04 & 27.67 \\
# NW-PFSP & 3.47 & 7.18 & 50.51 & 57.87 \\
# NPFSP & 13.53 & 8.88 & 16.29 & 25.58 \\
# HFSP & 13.34 & 6.58 & 11.94 & 66.54 \\
# PFSP & 7.49 & 2.54 & 10.61 & 7.03 \\
# SDST-PFSP & 8.82 & 4.41 & 30.75 & 28.24 \\
# TCT-PFSP & 10.31 & 3.31 & 21.48 & 26.69 \\
# TT-PFSP & 53.14 & 20.79 & 66.86 & 72.43 \\
# RCPSP & 0.93 & 0.46 & 3.46 & 4.26 \\
# MMRCPSP & 0.21 & 0.35 & 1.03 & 7.30 \\
# RCMPSP & -0.52 & -0.85 & 14.91 & 67.36 \\
# \bottomrule
# \end{tabular}

# %%
for instance_set in [SET1, SET2, SET3]:
    avg_gaps = res.loc[instance_set].mean().round(2).values
    text = '  &  '.join(str(gap) for gap in avg_gaps)
    print(f"& \\textit{{Average}} & {text} \\\\")
# Out:
# & \textit{Average} & 6.6  &  5.08  &  16.63  &  36.35 \\
# & \textit{Average} & 19.94  &  7.76  &  32.43  &  33.6 \\
# & \textit{Average} & 0.21  &  -0.01  &  6.47  &  26.31 \\

# %% [markdown]
# ### Best-known solutions

# %%
idcs = df.groupby(["problem", "instance"])["rpd"].idxmin().values
best = df.loc[idcs]
improvements = best[best["rpd"] < 0].sort_values(["problem", "instance"])
improvements.groupby("problem").count()
# Out:
#          solver  time_limit  instance  status  objective  lower_bound  time  \
# problem
# FJSP         30          30        30      30         30           30    30
# MMRCPSP      13          13        13      13         13           13    13
# NPFSP        37          37        37      37         37           37    37
# NW-PFSP      40          40        40      40         40           40    40
# RCMPSP     2025        2025      2025    2025       2025         2025  2025
# RCPSP        22          22        22      22         22           22    22
# TT-PFSP       3           3         3       3          3            3     3
#
#          category   bks  num_modes  num_resources  num_tasks   rpd   gap  \
# problem
# FJSP           30    30         30             30         30    30    30
# MMRCPSP        13    13         13             13         13    13    13
# NPFSP          37    37         37             37         37    37    37
# NW-PFSP        40    40         40             40         40    40    40
# RCMPSP       2025  2025       2025           2025       2025  2025  2025
# RCPSP          22    22         22             22         22    22    22
# TT-PFSP         3     3          3              3          3     3     3
#
#          feas  optimal  large
# problem
# FJSP       30       30     30
# MMRCPSP    13       13     13
# NPFSP      37       37     37
# NW-PFSP    40       40     40
# RCMPSP   2025     2025   2025
# RCPSP      22       22     22
# TT-PFSP     3        3      3

# %%
variants = ["MMRCPSP", "RCPSP"]
best = best[best["problem"].isin(variants)]
best[best["rpd"] < 0].sort_values(["problem", "instance"])
# Out:
#        problem       solver  time_limit       instance    status  objective  \
# 11941  MMRCPSP      ortools         900   J10010_5.txt  Feasible       29.0
# 11944  MMRCPSP      ortools         900   J10011_3.txt   Optimal       30.0
# 11991  MMRCPSP      ortools         900    J1001_5.txt  Feasible       39.0
# 12083  MMRCPSP      ortools         900   J10037_2.txt  Feasible       49.0
# 12091  MMRCPSP      ortools         900   J10038_5.txt  Feasible       40.0
# 12124  MMRCPSP      ortools         900   J10044_3.txt  Feasible       56.0
# 12182  MMRCPSP      ortools         900   J10055_1.txt  Feasible       47.0
# 12183  MMRCPSP      ortools         900   J10055_2.txt   Optimal       45.0
# 12428  MMRCPSP      ortools         900    J1009_2.txt  Feasible       35.0
# 12481  MMRCPSP      ortools         900    J5010_5.txt  Feasible       34.0
# 13739  MMRCPSP  cpoptimizer         900    J5043_3.txt  Feasible       67.0
# 12857  MMRCPSP      ortools         900     J507_1.txt  Feasible       43.0
# 13946  MMRCPSP  cpoptimizer         900    J5080_5.txt  Feasible       69.0
# 11418    RCPSP  cpoptimizer         900  RG300_104.txt  Feasible      972.0
# 11425    RCPSP  cpoptimizer         900  RG300_110.txt  Feasible     1019.0
# 11461    RCPSP  cpoptimizer         900  RG300_143.txt  Feasible     1416.0
# 11466    RCPSP  cpoptimizer         900  RG300_148.txt  Feasible     1422.0
# 11467    RCPSP  cpoptimizer         900  RG300_149.txt  Feasible     1556.0
# 11487    RCPSP  cpoptimizer         900  RG300_167.txt   Optimal       83.0
# 11511    RCPSP  cpoptimizer         900  RG300_189.txt  Feasible      302.0
# 11516    RCPSP  cpoptimizer         900  RG300_193.txt  Feasible      396.0
# 11564    RCPSP  cpoptimizer         900  RG300_236.txt  Feasible      843.0
# 11594    RCPSP  cpoptimizer         900  RG300_263.txt  Feasible     1054.0
# 11596    RCPSP  cpoptimizer         900  RG300_265.txt  Feasible     1112.0
# 11599    RCPSP  cpoptimizer         900  RG300_268.txt  Feasible     1109.0
# 11638    RCPSP  cpoptimizer         900  RG300_302.txt  Feasible     1570.0
# 11704    RCPSP  cpoptimizer         900  RG300_362.txt  Feasible      196.0
# 11770    RCPSP  cpoptimizer         900  RG300_421.txt  Feasible     1161.0
# 11771    RCPSP  cpoptimizer         900  RG300_422.txt  Feasible     1153.0
# 11779    RCPSP  cpoptimizer         900   RG300_43.txt  Feasible      165.0
# 11840    RCPSP  cpoptimizer         900   RG300_52.txt  Feasible      391.0
# 11842    RCPSP  cpoptimizer         900   RG300_54.txt  Feasible      395.0
# 11843    RCPSP  cpoptimizer         900   RG300_55.txt  Feasible      375.0
# 11845    RCPSP  cpoptimizer         900   RG300_57.txt  Feasible      381.0
# 11875    RCPSP  cpoptimizer         900   RG300_84.txt  Feasible      281.0
#
#        lower_bound    time  category   bks  num_modes  num_resources  \
# 11941    28.000000  900.02  MMLIB100    30        302              4
# 11944    30.000000  655.08  MMLIB100    31        302              4
# 11991    38.000000  900.06  MMLIB100    40        302              4
# 12083    48.000000  900.24  MMLIB100    50        302              4
# 12091    39.000000  900.03  MMLIB100    41        302              4
# 12124    55.000000  900.08  MMLIB100    57        302              4
# 12182    46.000000  900.08  MMLIB100    48        302              4
# 12183    45.000000  483.77  MMLIB100    46        302              4
# 12428    34.000000  900.02  MMLIB100    36        302              4
# 12481    33.000000  900.02   MMLIB50    35        152              4
# 13739    33.999966  900.00   MMLIB50    68        152              4
# 12857    42.000000  900.03   MMLIB50    44        152              4
# 13946    50.000000  900.00   MMLIB50    70        152              4
# 11418   759.000000  900.04     RG300   977        302              4
# 11425   751.000000  900.07     RG300  1027        302              4
# 11461   944.000000  900.04     RG300  1421        302              4
# 11466   941.000000  900.05     RG300  1423        302              4
# 11467  1042.000000  900.05     RG300  1558        302              4
# 11487    83.000000  653.18     RG300    84        302              4
# 11511   288.000000  900.04     RG300   303        302              4
# 11516   353.000000  900.03     RG300   397        302              4
# 11564   724.000000  900.03     RG300   844        302              4
# 11594   745.000000  900.06     RG300  1055        302              4
# 11596   788.000000  900.05     RG300  1114        302              4
# 11599   780.000000  900.04     RG300  1112        302              4
# 11638  1039.000000  900.05     RG300  1571        302              4
# 11704   185.000000  900.02     RG300   197        302              4
# 11770   822.000000  900.05     RG300  1165        302              4
# 11771   824.000000  900.03     RG300  1161        302              4
# 11779   163.000000  900.03     RG300   166        302              4
# 11840   373.000000  900.05     RG300   392        302              4
# 11842   377.000000  900.03     RG300   396        302              4
# 11843   363.000000  900.03     RG300   378        302              4
# 11845   366.000000  900.01     RG300   382        302              4
# 11875   277.000000  900.03     RG300   283        302              4
#
#        num_tasks       rpd        gap  feas  optimal  large
# 11941        102 -3.333333   3.448276  True    False  False
# 11944        102 -3.225806   0.000000  True     True  False
# 11991        102 -2.500000   2.564103  True    False  False
# 12083        102 -2.000000   2.040816  True    False  False
# 12091        102 -2.439024   2.500000  True    False  False
# 12124        102 -1.754386   1.785714  True    False  False
# 12182        102 -2.083333   2.127660  True    False  False
# 12183        102 -2.173913   0.000000  True     True  False
# 12428        102 -2.777778   2.857143  True    False  False
# 12481         52 -2.857143   2.941176  True    False  False
# 13739         52 -1.470588  49.253782  True    False  False
# 12857         52 -2.272727   2.325581  True    False  False
# 13946         52 -1.428571  27.536232  True    False  False
# 11418        302 -0.511771  21.913580  True    False  False
# 11425        302 -0.778968  26.300294  True    False  False
# 11461        302 -0.351865  33.333333  True    False  False
# 11466        302 -0.070274  33.825598  True    False  False
# 11467        302 -0.128370  33.033419  True    False  False
# 11487        302 -1.190476   0.000000  True     True  False
# 11511        302 -0.330033   4.635762  True    False  False
# 11516        302 -0.251889  10.858586  True    False  False
# 11564        302 -0.118483  14.116251  True    False  False
# 11594        302 -0.094787  29.316888  True    False  False
# 11596        302 -0.179533  29.136691  True    False  False
# 11599        302 -0.269784  29.666366  True    False  False
# 11638        302 -0.063654  33.821656  True    False  False
# 11704        302 -0.507614   5.612245  True    False  False
# 11770        302 -0.343348  29.198966  True    False  False
# 11771        302 -0.689061  28.534258  True    False  False
# 11779        302 -0.602410   1.212121  True    False  False
# 11840        302 -0.255102   4.603581  True    False  False
# 11842        302 -0.252525   4.556962  True    False  False
# 11843        302 -0.793651   3.200000  True    False  False
# 11845        302 -0.261780   3.937008  True    False  False
# 11875        302 -0.706714   1.423488  True    False  False

# %% [markdown]
# ## Extra

# %% [markdown]
# ### Naderi FJSP

# %%
bks = pd.read_csv(DATA_DIR / "bks.csv")
stats = pd.read_csv(DATA_DIR / "stats.csv")
results = pd.read_csv(DATA_DIR / "fjsp_naderi.csv")

extra_df = pd.merge(results, bks, on=["problem", "instance"])
extra_df = pd.merge(extra_df, stats, on=["problem", "instance"])
extra_df = preprocess(extra_df)
extra_df["rpd"].mean()
# Out:
# 7.553400719498263
