# %%
from pathlib import Path

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Constants

# %%
DATA_DIR = Path("../data")

SOLVERS = ["ortools", "cpoptimizer"]
TIME_LIMIT = [120, 900]

SET1 = ["JSP", "FJSP", "NW-PFSP", "NPFSP", "HFSP"]
SET2 = ["PFSP", "SDST-PFSP", "TCT-PFSP", "TT-PFSP"]
SET3 = ["RCPSP", "MMRCPSP", "RCMPSP"]

ALL = SET1 + SET2 + SET3

# %% [markdown]
# ## Helpers

# %%
def present(df, index=ALL):
    """
    Put time limit and solver as MultiIndex and sort by time limit and OR-tools first.
    """
    unstacked = df.unstack(level=[2, 1])
    columns = sorted(unstacked.columns, key=lambda x: (x[0], -ord(x[1][0])))
    unstacked = unstacked[columns]
    return unstacked.loc[index]

# %%
def latex(df, float_format="%.2f"):
    text = df.to_latex(float_format=float_format)
    text = text.replace("time_limit", "Time Limit")
    text = text.replace("_", "-")
    text = text.replace("NaN", "-")
    print(text)

# %% [markdown]
# ## Merging

# %%
bks = pd.read_csv(DATA_DIR / "bks.csv")
stats = pd.read_csv(DATA_DIR / "stats.csv")
results = pd.read_csv(DATA_DIR / "results.csv")

df = pd.merge(results, bks, on=["problem", "instance"])
# assert len(df) == len(results), "Not all results have a BKS entry."

df = pd.merge(df, stats, on=["problem", "instance"])
# assert len(df) == len(results), "Not all results have instance stats."

# %% [markdown]
# Debug cell to check which results don't have any bks. As long as these are "0.txt" instances, which are test instances, then it's fine.

# %%
merged = results.merge(bks, on=['problem', 'instance'], how='left', indicator=True)
not_in_bks = merged[merged['_merge'] == 'left_only']
not_in_bks['instance'].unique()
# Out:
# array(['0.txt'], dtype=object)

# %% [markdown]
# ## Preprocessing

# %%
def calculate_rpd(row):
    if row["bks"] != 0:
        return ((row["objective"] - row["bks"]) / row["bks"]) * 100
    else:
        # When the BKS is zero and objective is zero, we set RPD to 0, 
        # otherwise set to 100.
        return 0 if row["objective"] == row["bks"] else 100

def calculate_gap(row):
    if row["objective"] != 0:
        return ((row["objective"] - row["lower_bound"]) / row["objective"]) * 100
    else:
        # When the objective is zero, we set RPD to 0, otherwise set to 100.
        return 0 if row["objective"] == row["bks"] else 100
        
def preprocess(df):
    df = df.copy()
    
    df["rpd"] = df.apply(calculate_rpd, axis=1)
    if "lower_bound" in df.columns:
        df["gap"] = df.apply(calculate_gap, axis=1)
    df["feas"] = df["status"].isin(["Optimal", "Feasible"])
    df["optimal"] = df["status"] == "Optimal"
    df["large"] = df["num_modes"] >= 5000
    
    return df

# %%
df = preprocess(df)

# %% [markdown]
# ### Instance statistics

# %%
def agg_stats(x):
    return pd.Series({
        'min': x.min(),
        'avg': round(x.mean()),
        'max': x.max()
    })

# this ensures we only have each instance once (instead of 4x)
subset = df[(df['time_limit'] == 120) & (df['solver'] == 'ortools')] 

result = subset.groupby("problem").agg({
    'num_modes': ['count', 'min', 'mean', 'max'],
    # 'num_tasks': ['count', 'min', 'mean', 'max'],
    'num_resources': ['min', 'mean', 'max']
}).round(0)

columns = pd.MultiIndex.from_tuples([
    ('', 'instances'),
    ('Tasks', 'min'),
    ('Tasks', 'avg'),
    ('Tasks', 'max'),
    ('Resources', 'min'),
    ('Resources', 'avg'),
    ('Resources', 'max')
])

result.columns = columns
result = result.loc[ALL] # sort

for col in result.columns:
    result[col] = result[col].astype(int)

print(result.to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
#  &  & \multicolumn{3}{r}{Tasks} & \multicolumn{3}{r}{Resources} \\
#  & instances & min & avg & max & min & avg & max \\
# problem &  &  &  &  &  &  &  \\
# \midrule
# JSP & 242 & 36 & 511 & 2000 & 5 & 15 & 20 \\
# FJSP & 289 & 33 & 1581 & 14401 & 4 & 11 & 20 \\
# NW-PFSP & 360 & 100 & 12610 & 48000 & 5 & 31 & 60 \\
# NPFSP & 360 & 100 & 12610 & 48000 & 5 & 31 & 60 \\
# HFSP & 1440 & 750 & 3750 & 10000 & 15 & 30 & 50 \\
# PFSP & 120 & 100 & 1496 & 6000 & 5 & 19 & 60 \\
# SDST-PFSP & 360 & 100 & 661 & 2000 & 5 & 12 & 20 \\
# TCT-PFSP & 120 & 100 & 1496 & 6000 & 5 & 19 & 60 \\
# TT-PFSP & 135 & 500 & 1500 & 2500 & 10 & 30 & 50 \\
# RCPSP & 10080 & 32 & 122 & 302 & 3 & 4 & 4 \\
# MMRCPSP & 3240 & 152 & 202 & 302 & 4 & 4 & 4 \\
# RCMPSP & 2254 & 1488 & 1488 & 1488 & 4 & 4 & 4 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Feasibility

# %%
def percentage_feasible(feas):
    return sum(feas) / len(feas) * 100

groups = tl120.groupby(["problem", "solver"])
pct_feas = groups['feas'].apply(percentage_feasible)
latex(present(pct_feas), float_format= "%.2f")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[414], line 4
#       1 def percentage_feasible(feas):
#       2     return sum(feas) / len(feas) * 100
# ----> 4 groups = tl120.groupby(["problem", "solver"])
#       5 pct_feas = groups['feas'].apply(percentage_feasible)
#       6 latex(present(pct_feas), float_format= "%.2f")
#
# NameError: name 'tl120' is not defined

# %% [markdown]
# ### Optimal

# %%
def percentage_opt(row):
    return sum(row) / len(row) * 100

groups = df.groupby(["problem", "solver", "time_limit"])
pct_opt = groups['optimal'].apply(percentage_opt)
latex(present(pct_opt), float_format= "%.2f")
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{120} & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 33.06 & 36.36 & 41.32 & 47.11 \\
# FJSP & 48.10 & 35.29 & 58.13 & 38.41 \\
# NW-PFSP & 0.00 & 0.00 & 0.00 & 0.00 \\
# NPFSP & 4.44 & 6.11 & 6.11 & 8.06 \\
# HFSP & 0.00 & 0.00 & 0.14 & 0.00 \\
# PFSP & 11.67 & 25.00 & 17.50 & 30.83 \\
# SDST-PFSP & 0.00 & 0.00 & 0.00 & 1.11 \\
# TCT-PFSP & 0.00 & 0.00 & 0.00 & 0.00 \\
# TT-PFSP & 2.22 & 6.67 & 5.93 & 6.67 \\
# RCPSP & 63.69 & 63.61 & 65.16 & 64.64 \\
# MMRCPSP & 78.64 & 65.86 & 81.54 & 72.96 \\
# RCMPSP & 9.14 & 8.70 & 9.94 & 8.78 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Relative percentage deviation

# %%
def rpd(df, groups=["problem", "solver", "time_limit"]):
    subset = df[df["feas"]] # drop rows with infeasible solutions
    grouped = subset.groupby(groups)
    return grouped['rpd'].mean().round(2)

# %%
res = present(rpd(df))
latex(res)
res
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{120} & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 3.83 & 2.75 & 1.98 & 1.80 \\
# FJSP & 1.78 & 1.35 & 0.68 & 0.99 \\
# NW-PFSP & 4.62 & 24.39 & 3.47 & 7.18 \\
# NPFSP & 14.75 & 10.97 & 13.53 & 8.88 \\
# HFSP & 24.66 & 8.63 & 13.34 & 6.58 \\
# PFSP & 9.86 & 4.46 & 7.49 & 2.54 \\
# SDST-PFSP & 13.96 & 5.48 & 8.82 & 4.41 \\
# TCT-PFSP & 14.47 & 5.66 & 10.31 & 3.31 \\
# TT-PFSP & 84.66 & 31.70 & 53.14 & 20.79 \\
# RCPSP & 1.29 & 0.79 & 0.93 & 0.46 \\
# MMRCPSP & 0.32 & 0.51 & 0.18 & 0.27 \\
# RCMPSP & -0.42 & -0.70 & -0.52 & -0.85 \\
# \bottomrule
# \end{tabular}
# time_limit     120                 900
# solver     ortools cpoptimizer ortools cpoptimizer
# problem
# JSP           3.83        2.75    1.98        1.80
# FJSP          1.78        1.35    0.68        0.99
# NW-PFSP       4.62       24.39    3.47        7.18
# NPFSP        14.75       10.97   13.53        8.88
# HFSP         24.66        8.63   13.34        6.58
# PFSP          9.86        4.46    7.49        2.54
# SDST-PFSP    13.96        5.48    8.82        4.41
# TCT-PFSP     14.47        5.66   10.31        3.31
# TT-PFSP      84.66       31.70   53.14       20.79
# RCPSP         1.29        0.79    0.93        0.46
# MMRCPSP       0.32        0.51    0.18        0.27
# RCMPSP       -0.42       -0.70   -0.52       -0.85

# %%
for instance_set in [SET1, SET2, SET3]:
    avg_gaps = res.loc[instance_set].mean().round(2).values
    text = '  &  '.join(str(gap) for gap in avg_gaps)
    print(f"& \\textit{{Average}} & {text} \\\\")
# Out:
# & \textit{Average} & 9.93  &  9.62  &  6.6  &  5.09 \\
# & \textit{Average} & 30.74  &  11.82  &  19.94  &  7.76 \\
# & \textit{Average} & 0.4  &  0.2  &  0.2  &  -0.04 \\

# %% [markdown]
# ### RPD by instance size

# %%
tl900 = df[df['time_limit'] == 900]
res = rpd(tl900, ["problem", "solver", "large"])
res = present(res)
latex(res)
res
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# large & \multicolumn{2}{r}{False} & \multicolumn{2}{r}{True} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 1.98 & 1.80 & - & - \\
# FJSP & 0.49 & 0.69 & 2.57 & 3.87 \\
# NW-PFSP & 6.22 & 3.70 & 1.72 & 9.40 \\
# NPFSP & 9.07 & 4.70 & 16.36 & 11.54 \\
# HFSP & 8.63 & 5.42 & 23.72 & 9.12 \\
# PFSP & 6.49 & 2.00 & 18.49 & 8.50 \\
# SDST-PFSP & 8.82 & 4.41 & - & - \\
# TCT-PFSP & 10.39 & 3.22 & 9.41 & 4.33 \\
# TT-PFSP & 53.14 & 20.79 & - & - \\
# RCPSP & 0.93 & 0.46 & - & - \\
# MMRCPSP & 0.18 & 0.27 & - & - \\
# RCMPSP & -0.52 & -0.85 & - & - \\
# \bottomrule
# \end{tabular}
# large       False               True
# solver    ortools cpoptimizer ortools cpoptimizer
# problem
# JSP          1.98        1.80     NaN         NaN
# FJSP         0.49        0.69    2.57        3.87
# NW-PFSP      6.22        3.70    1.72        9.40
# NPFSP        9.07        4.70   16.36       11.54
# HFSP         8.63        5.42   23.72        9.12
# PFSP         6.49        2.00   18.49        8.50
# SDST-PFSP    8.82        4.41     NaN         NaN
# TCT-PFSP    10.39        3.22    9.41        4.33
# TT-PFSP     53.14       20.79     NaN         NaN
# RCPSP        0.93        0.46     NaN         NaN
# MMRCPSP      0.18        0.27     NaN         NaN
# RCMPSP      -0.52       -0.85     NaN         NaN

# %%
for instance_set in [SET1, SET2, SET3]:
    avg_gaps = res.loc[instance_set].mean().round(2).values
    text = '  &  '.join(str(gap) for gap in avg_gaps)
    print(f"& \\textit{{Average}} & {text} \\\\")
# Out:
# & \textit{Average} & 5.28  &  3.26  &  11.09  &  8.48 \\
# & \textit{Average} & 19.71  &  7.6  &  13.95  &  6.42 \\
# & \textit{Average} & 0.2  &  -0.04  &  nan  &  nan \\

# %% [markdown]
# ## Optimality gap

# %%
def gap(df, groups=["problem", "solver", "time_limit"]):
    subset = df[df["feas"]] # drop rows with infeasible solutions
    grouped = subset.groupby(groups)
    return grouped['gap'].mean().round(2)

# %%
res = present(gap(df))
latex(res)
res
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# Time Limit & \multicolumn{2}{r}{120} & \multicolumn{2}{r}{900} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 5.27 & 5.11 & 3.40 & 4.09 \\
# FJSP & 1.98 & 28.06 & 1.04 & 27.67 \\
# NW-PFSP & 51.38 & 69.72 & 50.51 & 57.87 \\
# NPFSP & 17.07 & 50.47 & 16.29 & 25.58 \\
# HFSP & 19.47 & 67.20 & 11.94 & 66.54 \\
# PFSP & 12.22 & 8.70 & 10.61 & 7.03 \\
# SDST-PFSP & 34.59 & 28.94 & 30.75 & 28.24 \\
# TCT-PFSP & 26.40 & 29.96 & 21.48 & 26.69 \\
# TT-PFSP & 75.13 & 74.01 & 66.86 & 72.43 \\
# RCPSP & 3.87 & 4.62 & 3.46 & 4.26 \\
# MMRCPSP & 1.27 & 8.27 & 0.94 & 6.65 \\
# RCMPSP & 33.80 & 67.43 & 14.91 & 67.36 \\
# \bottomrule
# \end{tabular}
# time_limit     120                 900
# solver     ortools cpoptimizer ortools cpoptimizer
# problem
# JSP           5.27        5.11    3.40        4.09
# FJSP          1.98       28.06    1.04       27.67
# NW-PFSP      51.38       69.72   50.51       57.87
# NPFSP        17.07       50.47   16.29       25.58
# HFSP         19.47       67.20   11.94       66.54
# PFSP         12.22        8.70   10.61        7.03
# SDST-PFSP    34.59       28.94   30.75       28.24
# TCT-PFSP     26.40       29.96   21.48       26.69
# TT-PFSP      75.13       74.01   66.86       72.43
# RCPSP         3.87        4.62    3.46        4.26
# MMRCPSP       1.27        8.27    0.94        6.65
# RCMPSP       33.80       67.43   14.91       67.36

# %% [markdown]
# ## Results

# %%
columns = sorted(unstacked.columns, key=lambda x: (x[0], -ord(x[1][0])))
unstacked = unstacked[columns]
return unstacked.loc[index]

# %%
df = preprocess(df)
tl900 = df[(df["time_limit"] == 900) & df["feas"]]
res = tl900.groupby(["problem","solver"])[['rpd', 'gap']].mean()
unstacked = res.unstack()
columns = sorted(unstacked.columns, key=lambda x: (-ord(x[0][0]), -ord(x[1][0])))
unstacked = unstacked[columns]
res = unstacked.loc[ALL]
latex(res)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#  & \multicolumn{2}{r}{rpd} & \multicolumn{2}{r}{gap} \\
# solver & ortools & cpoptimizer & ortools & cpoptimizer \\
# problem &  &  &  &  \\
# \midrule
# JSP & 1.98 & 1.80 & 3.40 & 4.09 \\
# FJSP & 0.68 & 0.99 & 1.04 & 27.67 \\
# NW-PFSP & 3.47 & 7.18 & 50.51 & 57.87 \\
# NPFSP & 13.53 & 8.88 & 16.29 & 25.58 \\
# HFSP & 13.34 & 6.58 & 11.94 & 66.54 \\
# PFSP & 7.49 & 2.54 & 10.61 & 7.03 \\
# SDST-PFSP & 8.82 & 4.41 & 30.75 & 28.24 \\
# TCT-PFSP & 10.31 & 3.31 & 21.48 & 26.69 \\
# TT-PFSP & 53.14 & 20.79 & 66.86 & 72.43 \\
# RCPSP & 0.93 & 0.46 & 3.46 & 4.26 \\
# MMRCPSP & 0.18 & 0.27 & 0.94 & 6.65 \\
# RCMPSP & -0.52 & -0.85 & 14.91 & 67.36 \\
# \bottomrule
# \end{tabular}

# %%
for instance_set in [SET1, SET2, SET3]:
    avg_gaps = res.loc[instance_set].mean().round(2).values
    text = '  &  '.join(str(gap) for gap in avg_gaps)
    print(f"& \\textit{{Average}} & {text} \\\\")
# Out:
# & \textit{Average} & 6.6  &  5.08  &  16.63  &  36.35 \\
# & \textit{Average} & 19.94  &  7.76  &  32.43  &  33.6 \\
# & \textit{Average} & 0.2  &  -0.04  &  6.44  &  26.09 \\

# %% [markdown]
# ### Best-known solutions

# %%
idcs = df.groupby(["problem", "instance"])["rpd"].idxmin().values
best = df.loc[idcs]
improvements = best[best["rpd"] < 0].sort_values(["problem", "instance"])
improvements.groupby("problem").count()
# Out:
#          solver  time_limit  instance  status  objective  lower_bound  time  \
# problem
# FJSP         30          30        30      30         30           30    30
# MMRCPSP      13          13        13      13         13           13    13
# NPFSP        37          37        37      37         37           37    37
# NW-PFSP      40          40        40      40         40           40    40
# RCMPSP     2025        2025      2025    2025       2025         2025  2025
# RCPSP        22          22        22      22         22           22    22
# TT-PFSP       3           3         3       3          3            3     3
#
#          category   bks  num_modes  num_resources  num_tasks   rpd   gap  \
# problem
# FJSP           30    30         30             30         30    30    30
# MMRCPSP        13    13         13             13         13    13    13
# NPFSP          37    37         37             37         37    37    37
# NW-PFSP        40    40         40             40         40    40    40
# RCMPSP       2025  2025       2025           2025       2025  2025  2025
# RCPSP          22    22         22             22         22    22    22
# TT-PFSP         3     3          3              3          3     3     3
#
#          feas  optimal  large
# problem
# FJSP       30       30     30
# MMRCPSP    13       13     13
# NPFSP      37       37     37
# NW-PFSP    40       40     40
# RCMPSP   2025     2025   2025
# RCPSP      22       22     22
# TT-PFSP     3        3      3

# %%
variants = ["MMRCPSP", "RCPSP"]
best = best[best["problem"].isin(variants)]
best[best["rpd"] < 0].sort_values(["problem", "instance"])
# Out:
#        problem       solver  time_limit       instance    status  objective  \
# 57362  MMRCPSP      ortools         900   J10010_5.txt  Feasible       29.0
# 57368  MMRCPSP      ortools         900   J10011_3.txt   Optimal       30.0
# 57462  MMRCPSP      ortools         900    J1001_5.txt  Feasible       39.0
# 57646  MMRCPSP      ortools         900   J10037_2.txt  Feasible       49.0
# 57662  MMRCPSP      ortools         900   J10038_5.txt  Feasible       40.0
# 54488  MMRCPSP      ortools         120   J10044_3.txt  Feasible       56.0
# 57844  MMRCPSP      ortools         900   J10055_1.txt  Feasible       47.0
# 57846  MMRCPSP      ortools         900   J10055_2.txt   Optimal       45.0
# 58336  MMRCPSP      ortools         900    J1009_2.txt  Feasible       35.0
# 58540  MMRCPSP      ortools         900    J5010_5.txt  Feasible       34.0
# 65732  MMRCPSP  cpoptimizer         900    J5043_3.txt  Feasible       67.0
# 60044  MMRCPSP      ortools         900     J507_1.txt  Feasible       43.0
# 66560  MMRCPSP  cpoptimizer         900    J5080_5.txt  Feasible       69.0
# 52128    RCPSP  cpoptimizer         900  RG300_104.txt  Feasible      972.0
# 52156    RCPSP  cpoptimizer         900  RG300_110.txt  Feasible     1019.0
# 52300    RCPSP  cpoptimizer         900  RG300_143.txt  Feasible     1416.0
# 52320    RCPSP  cpoptimizer         900  RG300_148.txt  Feasible     1422.0
# 52324    RCPSP  cpoptimizer         900  RG300_149.txt  Feasible     1556.0
# 52404    RCPSP  cpoptimizer         900  RG300_167.txt   Optimal       83.0
# 42420    RCPSP  cpoptimizer         120  RG300_189.txt  Feasible      302.0
# 52520    RCPSP  cpoptimizer         900  RG300_193.txt  Feasible      396.0
# 52712    RCPSP  cpoptimizer         900  RG300_236.txt  Feasible      843.0
# 52832    RCPSP  cpoptimizer         900  RG300_263.txt  Feasible     1054.0
# 52840    RCPSP  cpoptimizer         900  RG300_265.txt  Feasible     1112.0
# 52852    RCPSP  cpoptimizer         900  RG300_268.txt  Feasible     1109.0
# 53008    RCPSP  cpoptimizer         900  RG300_302.txt  Feasible     1570.0
# 53272    RCPSP  cpoptimizer         900  RG300_362.txt  Feasible      196.0
# 53536    RCPSP  cpoptimizer         900  RG300_421.txt  Feasible     1161.0
# 53540    RCPSP  cpoptimizer         900  RG300_422.txt  Feasible     1153.0
# 53572    RCPSP  cpoptimizer         900   RG300_43.txt  Feasible      165.0
# 53816    RCPSP  cpoptimizer         900   RG300_52.txt  Feasible      391.0
# 53824    RCPSP  cpoptimizer         900   RG300_54.txt  Feasible      395.0
# 53828    RCPSP  cpoptimizer         900   RG300_55.txt  Feasible      375.0
# 53836    RCPSP  cpoptimizer         900   RG300_57.txt  Feasible      381.0
# 53956    RCPSP  cpoptimizer         900   RG300_84.txt  Feasible      281.0
#
#        lower_bound    time  category     bks  num_modes  num_resources  \
# 57362    28.000000  900.02  MMLIB100    30.0        302              4
# 57368    30.000000  655.08  MMLIB100    31.0        302              4
# 57462    38.000000  900.06  MMLIB100    40.0        302              4
# 57646    48.000000  900.24  MMLIB100    50.0        302              4
# 57662    39.000000  900.03  MMLIB100    41.0        302              4
# 54488    55.000000  120.06  MMLIB100    57.0        302              4
# 57844    46.000000  900.08  MMLIB100    48.0        302              4
# 57846    45.000000  483.77  MMLIB100    46.0        302              4
# 58336    34.000000  900.02  MMLIB100    36.0        302              4
# 58540    33.000000  900.02   MMLIB50    35.0        152              4
# 65732    33.999966  900.00   MMLIB50    68.0        152              4
# 60044    42.000000  900.03   MMLIB50    44.0        152              4
# 66560    50.000000  900.00   MMLIB50    70.0        152              4
# 52128   759.000000  900.04     RG300   977.0        302              4
# 52156   751.000000  900.07     RG300  1027.0        302              4
# 52300   944.000000  900.04     RG300  1421.0        302              4
# 52320   941.000000  900.05     RG300  1423.0        302              4
# 52324  1042.000000  900.05     RG300  1558.0        302              4
# 52404    83.000000  653.18     RG300    84.0        302              4
# 42420   288.000000  120.01     RG300   303.0        302              4
# 52520   353.000000  900.03     RG300   397.0        302              4
# 52712   724.000000  900.03     RG300   844.0        302              4
# 52832   745.000000  900.06     RG300  1055.0        302              4
# 52840   788.000000  900.05     RG300  1114.0        302              4
# 52852   780.000000  900.04     RG300  1112.0        302              4
# 53008  1039.000000  900.05     RG300  1571.0        302              4
# 53272   185.000000  900.02     RG300   197.0        302              4
# 53536   822.000000  900.05     RG300  1165.0        302              4
# 53540   824.000000  900.03     RG300  1161.0        302              4
# 53572   163.000000  900.03     RG300   166.0        302              4
# 53816   373.000000  900.05     RG300   392.0        302              4
# 53824   377.000000  900.03     RG300   396.0        302              4
# 53828   363.000000  900.03     RG300   378.0        302              4
# 53836   366.000000  900.01     RG300   382.0        302              4
# 53956   277.000000  900.03     RG300   283.0        302              4
#
#        num_tasks       rpd        gap  feas  optimal  large
# 57362        102 -3.333333   3.448276  True    False  False
# 57368        102 -3.225806   0.000000  True     True  False
# 57462        102 -2.500000   2.564103  True    False  False
# 57646        102 -2.000000   2.040816  True    False  False
# 57662        102 -2.439024   2.500000  True    False  False
# 54488        102 -1.754386   1.785714  True    False  False
# 57844        102 -2.083333   2.127660  True    False  False
# 57846        102 -2.173913   0.000000  True     True  False
# 58336        102 -2.777778   2.857143  True    False  False
# 58540         52 -2.857143   2.941176  True    False  False
# 65732         52 -1.470588  49.253782  True    False  False
# 60044         52 -2.272727   2.325581  True    False  False
# 66560         52 -1.428571  27.536232  True    False  False
# 52128        302 -0.511771  21.913580  True    False  False
# 52156        302 -0.778968  26.300294  True    False  False
# 52300        302 -0.351865  33.333333  True    False  False
# 52320        302 -0.070274  33.825598  True    False  False
# 52324        302 -0.128370  33.033419  True    False  False
# 52404        302 -1.190476   0.000000  True     True  False
# 42420        302 -0.330033   4.635762  True    False  False
# 52520        302 -0.251889  10.858586  True    False  False
# 52712        302 -0.118483  14.116251  True    False  False
# 52832        302 -0.094787  29.316888  True    False  False
# 52840        302 -0.179533  29.136691  True    False  False
# 52852        302 -0.269784  29.666366  True    False  False
# 53008        302 -0.063654  33.821656  True    False  False
# 53272        302 -0.507614   5.612245  True    False  False
# 53536        302 -0.343348  29.198966  True    False  False
# 53540        302 -0.689061  28.534258  True    False  False
# 53572        302 -0.602410   1.212121  True    False  False
# 53816        302 -0.255102   4.603581  True    False  False
# 53824        302 -0.252525   4.556962  True    False  False
# 53828        302 -0.793651   3.200000  True    False  False
# 53836        302 -0.261780   3.937008  True    False  False
# 53956        302 -0.706714   1.423488  True    False  False

# %% [markdown]
# ## Extra

# %% [markdown]
# ### Naderi FJSP

# %%
bks = pd.read_csv(DATA_DIR / "bks.csv")
stats = pd.read_csv(DATA_DIR / "stats.csv")
results = pd.read_csv(DATA_DIR / "fjsp_naderi.csv")

extra_df = pd.merge(results, bks, on=["problem", "instance"])
extra_df = pd.merge(extra_df, stats, on=["problem", "instance"])
extra_df = preprocess(extra_df)
extra_df["rpd"].mean()
# Out:
# 7.553400719498263
